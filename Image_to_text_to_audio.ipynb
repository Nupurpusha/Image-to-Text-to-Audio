# %% [markdown]
# <a href="https://colab.research.google.com/github/Nupurpusha/Image-to-Text-to-Audio/blob/main/Image_to_text_to_audio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !sudo apt install tesseract-ocr #to extract the text from image without the text outlines.
# !pip install pytesseract
# !pip install gTTS #google translate text to speech API
# !pip install Pillow==9.0.0 #adds image processesing ability to the python interpreter
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# tesseract-ocr is already the newest version (4.1.1-2.1build1).
# 0 upgraded, 0 newly installed, 0 to remove and 45 not upgraded.
# ...

# %%
import pytesseract
from PIL import Image
import gtts

# %%
img = Image.open('/content/Image.png')
print(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=245x148 at 0x7E99694F2BF0>

# %%
result = pytesseract.image_to_string(img)
print(result)
tts = gtts.gTTS(result)
tts.save("hello.mp3")
# Out:
# Tt was the best of
# times, it was the worst
# of times, it was the age
# of wisdom, it was the
# age of foolishness...

# %%
from IPython.display import Audio

audio_file = "hello.mp3"

Audio(audio_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
